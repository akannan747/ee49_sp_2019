# %%
import numpy as np
import matplotlib.pyplot as plot

resistance = [108, 149, 196, 225, 264, 394, 515, 643, 819, 1028]
voltage = [1.96, 2.4, 3.36, 3.81, 4.17, 4.58, 4.72, 4.79, 4.85, 4.89]
current = [16.74, 16, 16.4, 16.32, 15, 11.35, 8.97, 7.32, 5.83, 4.67]
power = [32.81, 38.4, 55.1, 62.17, 62.55, 51.98, 42.33, 35.06, 28.28, 22.84]
log_res = np.log(resistance)

plot.semilogx(resistance, voltage,'.')
plot.semilogx(resistance, current,'.')
plot.semilogx(resistance, power,'.')
plot.xlabel("LOG(RESISTANCE)")
plot.ylabel("VOLTAGE, POWER, CURRENT")
plot.show()
#BLUE IS VOLTAGE
#ORANGE IS CURRENT17 mA1
#GREEN IS POWER
